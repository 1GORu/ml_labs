# %% [markdown]
# # Распознавание "морд" при помощи SVM и kernel trick

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

plt.style.use('ggplot')

# %% [markdown]
# # Описание набора данных

# %% [markdown]
# В этом задании вам предлагается построить классификатор, обученный на изображениях лиц. Сначала загрузим необходимый набор данных и посмотрим, что он из себя представляет.
#
# Таблица содержит "распрямленные" представления изображений лиц людей.
#
# Изначально каждое изображение — матрица размера $62 \times 47$, значения которой, предположительно, нормированы к диапазону $[0, 1]$ из диапазона $[0, 255] \cap \mathbb Z$. Сами значения отвечают за интенсивность пикселя: чем значение больше, тем пиксель светлее.
#
# Обратите внимание, из картинки (или, что то же самое, матрицы) размера $62 \times 47$ получился вектор длины $2914 = 62 \cdot 47$.
#
# Колонка <code>label</code> отвечает за имя человека, изображенного на картинке.

# %%
df = pd.read_csv('persons_pics_train.csv')
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.379085  0.312418  0.352941  0.445752  0.466667  0.473203  0.484967
# 1  0.450980  0.466667  0.512418  0.509804  0.450980  0.458824  0.516340
# 2  0.589542  0.614379  0.688889  0.729412  0.738562  0.775163  0.789543
# 3  0.390850  0.432680  0.499346  0.562091  0.597386  0.644444  0.670588
# 4  0.645752  0.626144  0.605229  0.585621  0.602614  0.664052  0.701961
#
#           7         8         9  ...      2905      2906      2907      2908  \
# 0  0.513725  0.545098  0.571242  ...  0.597386  0.620915  0.732026  0.852288
# 1  0.571242  0.607843  0.618301  ...  0.430065  0.453595  0.679739  0.934640
# 2  0.806536  0.820915  0.837908  ...  0.733333  0.854902  0.937255  0.624837
# 3  0.650980  0.637908  0.639216  ...  0.713726  0.898039  0.968627  0.959477
# 4  0.709804  0.733333  0.771242  ...  0.115033  0.129412  0.132026  0.129412
#
#        2909      2910      2911      2912      2913          label
# 0  0.921569  0.937255  0.941176  0.950327  0.946405  John Ashcroft
# 1  0.985621  0.981699  0.963399  0.938562  0.874510   Ariel Sharon
# 2  0.128105  0.082353  0.107190  0.095425  0.100654   Colin Powell
# 3  0.832680  0.443137  0.266667  0.303268  0.313725  Jean Chretien
# 4  0.155556  0.171242  0.167320  0.176471  0.183007   Colin Powell
#
# [5 rows x 2915 columns]

# %% [markdown]
# Убедимся в том, что перед нами действительно изображения лиц людей. Возьмем первые $15$ строк из таблицы исходных данных и построим соответствующие им изображения:

# %%
def get_img_by_row(row):
    return row.drop('label').astype(float).to_numpy().reshape(62,47), row['label']

# %%
fig, ax = plt.subplots(3, 5)
for i, axi in enumerate(ax.flat):
    img, lbl = get_img_by_row(df.iloc[i])
    axi.imshow(img, cmap='gray')
    axi.set(xticks=[], yticks=[],
            xlabel=lbl.split()[-1])
# plt.savefig('persons_pics_img_for_description.png', dpi = 300, bbox_inches='tight')

# %%
subset = df[df.label == 'John Ashcroft'].reset_index(drop=True)
fig, ax = plt.subplots(3, 5)
for i, axi in enumerate(ax.flat):
    img, lbl = get_img_by_row(subset.iloc[i])
    axi.imshow(img, cmap='gray')
    axi.set(xticks=[], yticks=[], xlabel=lbl.split()[-1])

# %% [markdown]
# Крупнее

# %%
plt.imshow(df.iloc[0].drop('label').astype(float).to_numpy().reshape(62,47), cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # Немного озорства

# %% [markdown]
# Определите число различных людей, фотографии которых содержатся в рассматриваемом наборе данных:

# %%
df.label.nunique()
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Постройте гистограмму распределения объектов по классам и вычислите долю объектов каждого класса:

# %%
counts = df.label.value_counts(normalize=True).sort_values()
counts.plot(kind='barh')
plt.xlabel('proportion')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
counts.round(3)
# Out:
# label
# Serena Williams      0.033
# Jacques Chirac       0.033
# John Ashcroft        0.034
# Jean Chretien        0.035
# Junichiro Koizumi    0.038
# Hugo Chavez          0.045
# Ariel Sharon         0.049
# Gerhard Schroeder    0.070
# Donald Rumsfeld      0.078
# Tony Blair           0.092
# Colin Powell         0.152
# George W Bush        0.340
# Name: proportion, dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# На основе имеющихся данных поставьте в соответствие каждому человеку один вектор, координаты которого являются средним соответствующих координат всех векторов, отождествленных с этим человеком:

# %%
mean_faces = df.groupby('label').mean()
mean_faces
# Out:
#                           0         1         2         3         4         5  \
# label
# Ariel Sharon       0.501398  0.514811  0.532609  0.551714  0.569754  0.577456
# Colin Powell       0.433512  0.441147  0.456248  0.471947  0.486730  0.513732
# Donald Rumsfeld    0.404810  0.417260  0.442731  0.474028  0.507938  0.541659
# George W Bush      0.348179  0.360263  0.381659  0.416669  0.457154  0.488335
# Gerhard Schroeder  0.210162  0.228210  0.268255  0.328344  0.389332  0.447115
# Hugo Chavez        0.206885  0.205142  0.240828  0.300806  0.370196  0.427712
# Jacques Chirac     0.348010  0.368152  0.405704  0.436988  0.462686  0.498693
# Jean Chretien      0.388958  0.412488  0.446614  0.487637  0.526158  0.563315
# John Ashcroft      0.337894  0.334379  0.337662  0.357037  0.384779  0.397182
# Junichiro Koizumi  0.268384  0.253672  0.249699  0.257875  0.297373  0.352044
# Serena Williams    0.412983  0.390434  0.359091  0.333541  0.337136  0.352852
# Tony Blair         0.327922  0.342955  0.363163  0.401854  0.456177  0.503311
#
#                           6         7         8         9  ...      2904  \
# label                                                      ...
# Ariel Sharon       0.581820  0.591835  0.604465  0.612589  ...  0.396400
# Colin Powell       0.545157  0.566514  0.581556  0.592924  ...  0.437869
# Donald Rumsfeld    0.560112  0.571838  0.585773  0.602386  ...  0.494917
# George W Bush      0.515398  0.536075  0.551153  0.565662  ...  0.385818
# Gerhard Schroeder  0.495003  0.527655  0.549441  0.569457  ...  0.414969
# Hugo Chavez        0.471939  0.512702  0.545251  0.562070  ...  0.337647
# Jacques Chirac     0.531135  0.553060  0.574629  0.594029  ...  0.453832
# Jean Chretien      0.594827  0.628981  0.665026  0.685774  ...  0.526380
# John Ashcroft      0.412375  0.431924  0.449441  0.466986  ...  0.472651
# Junichiro Koizumi  0.403306  0.441394  0.470819  0.494656  ...  0.505652
# Serena Williams    0.370113  0.384551  0.403743  0.423737  ...  0.236215
# Tony Blair         0.551355  0.596078  0.627837  0.647059  ...  0.488653
#
#                        2905      2906      2907      2908      2909      2910  \
# label
# Ariel Sharon       0.433947  0.478291  0.519920  0.532549  0.515656  0.498220
# Colin Powell       0.471798  0.512067  0.534615  0.532176  0.510006  0.477586
# Donald Rumsfeld    0.546837  0.562307  0.558627  0.549426  0.525947  0.500603
# George W Bush      0.414092  0.441074  0.461325  0.470275  0.459067  0.447653
# Gerhard Schroeder  0.430937  0.469281  0.494596  0.496718  0.482550  0.442252
# Hugo Chavez        0.360523  0.372200  0.385926  0.394662  0.392309  0.384989
# Jacques Chirac     0.469935  0.480957  0.486067  0.510933  0.537998  0.542751
# Jean Chretien      0.574190  0.583452  0.555667  0.499764  0.455180  0.426060
# John Ashcroft      0.468468  0.475759  0.489092  0.512999  0.540944  0.534524
# Junichiro Koizumi  0.530437  0.561169  0.558657  0.542304  0.537896  0.532359
# Serena Williams    0.246286  0.261943  0.274302  0.291474  0.308200  0.322460
# Tony Blair         0.500900  0.512108  0.526133  0.541498  0.552277  0.542077
#
#                        2911      2912      2913
# label
# Ariel Sharon       0.486657  0.466928  0.437687
# Colin Powell       0.448119  0.410659  0.379605
# Donald Rumsfeld    0.475550  0.431893  0.391738
# George W Bush      0.430523  0.399620  0.376584
# Gerhard Schroeder  0.428477  0.426875  0.411118
# Hugo Chavez        0.371503  0.372440  0.374052
# Jacques Chirac     0.505853  0.456625  0.434997
# Jean Chretien      0.415353  0.414713  0.397608
# John Ashcroft      0.524415  0.527495  0.527495
# Junichiro Koizumi  0.516750  0.498347  0.509753
# Serena Williams    0.334492  0.348247  0.361854
# Tony Blair         0.516072  0.480853  0.444680
#
# [12 rows x 2914 columns]

# %% [markdown]
# Вычислите координату с индексом $0$ усредненного вектора, соответствующего человеку из вашего индивидуального задания:

# %%
mean_faces.loc['Gerhard Schroeder', '0']
# Out:
# np.float64(0.21016234977419354)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Используя усредненные векторы, постройте изображения всех людей из набора данных:

# %%
fig, axes = plt.subplots(2, 6, figsize=(15, 10))
axes = axes.flatten()

for i, (person, face_vector) in enumerate(mean_faces.iterrows()):
    img = face_vector.to_numpy().reshape(62, 47)
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(person)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В качестве меры "схожести" двух объектов часто используют так называемое [косинусное сходство](https://en.wikipedia.org/wiki/Cosine_similarity). Не следует путать с косинусным расстоянием.
#
# Постройте матрицу "схожести" объектов на основе их усредненных векторов. Для визуализации рекомендуем использовать тепловую карту, например, [из библиотеки seaborn](https://seaborn.pydata.org/generated/seaborn.heatmap.html).

# %%
similarity_matrix = cosine_similarity(mean_faces)
sim_df = pd.DataFrame(
    similarity_matrix,
    index=mean_faces.index,
    columns=mean_faces.index
)

plt.figure(figsize=(10, 8))
sns.heatmap(
    sim_df,
    annot=True,
    fmt=".2f",
    cmap='viridis',
    square=True,
    cbar=False
)

plt.xticks(rotation=45, ha='right')
plt.xlabel('')
plt.yticks(rotation=0)
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Определите косинусное сходство для пары людей из вашего индивидуального задания на основе соответствующих им "усредненных" векторов:

# %%
sim_df.loc['Donald Rumsfeld', 'Serena Williams']
# Out:
# np.float64(0.9866056618941138)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Построение модели

# %% [markdown]
# При помощи <code>train_test_split()</code> разделите набор данных на тренировочный и тестовый с параметрами, указанными в вашем индивидуальном задании. Используйте стратификацию по колонке <code>label</code>:

# %%
X = df.drop('label', axis=1)
y = df.label

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=5,
    stratify=y
)

# %% [markdown]
# ## Первое приближение: базовый SVM классификатор с линейным ядром.

# %% [markdown]
# Обучите модель <code>SVC()</code> на тренировочном наборе данных с параметрами, указанными в вашем индивидуальном задании:

# %%
model = SVC(kernel='linear', random_state=5)
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=5)

# %% [markdown]
# Оцените модель на тестовых данных. Вычислите <code>f1_score(average='weighted')</code>:

# %%
y_pred = model.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f'F1-score: {f1:.3f}')
# Out:
# F1-score: 0.741

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В целом, достаточно неплохой результат, но имеет смысл попробовать подобрать параметры.

# %% [markdown]
# ## Подбор гиперпараметров

# %% [markdown]
# Используя <code>GridSearchCV()</code>, осуществите подбор гиперпараметров, указанных в вашем задании. Отдельно обратите внимание на время обучения моделей

# %%
# %%time
tuned_parameters = [{
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': [1e-3, 1e-4],
    'C': [1, 10, 100, 1000],
    'class_weight': [None, 'balanced'],
    'random_state': [5]
}]

cv = GridSearchCV(SVC(), tuned_parameters, refit=True, verbose=3)
cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.778 total time=   2.6s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   3.3s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.825 total time=   2.4s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.802 total time=   2.8s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.769 total time=   2.0s
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.377 total time=   2.8s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.358 total time=   3.2s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.373 total time=   1.5s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.373 total time=   1.6s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.363 total time=   1.6s
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.425 total time=   1.8s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.396 total time=   1.9s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.415 total time=   2.3s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.401 total time=   2.4s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.382 total time=   1.9s
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.344 total time=   1.5s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.6s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.5s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.5s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.6s
# [CV 1/5] END C=1, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.778 total time=   1.3s
# [CV 2/5] END C=1, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.764 total time=   1.4s
# [CV 3/5] END C=1, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.825 total time=   1.4s
# [CV 4/5] END C=1, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.802 total time=   1.2s
# [CV 5/5] END C=1, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.769 total time=   1.2s
# [CV 1/5] END C=1, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.344 total time=   1.3s
# [CV 2/5] END C=1, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   1.3s
# [CV 3/5] END C=1, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   1.4s
# [CV 4/5] END C=1, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   1.3s
# [CV 5/5] END C=1, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   1.3s
# [CV 1/5] END C=1, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.344 total time=   2.1s
# [CV 2/5] END C=1, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.340 total time=   2.1s
# [CV 3/5] END C=1, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.340 total time=   1.9s
# [CV 4/5] END C=1, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.340 total time=   1.8s
# [CV 5/5] END C=1, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.340 total time=   1.9s
# [CV 1/5] END C=1, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.344 total time=   1.6s
# [CV 2/5] END C=1, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.6s
# [CV 3/5] END C=1, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.8s
# [CV 4/5] END C=1, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.9s
# [CV 5/5] END C=1, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.340 total time=   1.6s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.778 total time=   1.2s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   1.2s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.821 total time=   1.3s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.802 total time=   1.2s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.769 total time=   1.2s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.316 total time=   2.5s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.325 total time=   2.7s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.325 total time=   2.3s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.392 total time=   2.4s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.316 total time=   2.3s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.325 total time=   2.8s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.344 total time=   3.1s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.354 total time=   3.2s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.406 total time=   2.8s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.311 total time=   2.7s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.321 total time=   3.0s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.104 total time=   2.9s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.179 total time=   2.7s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.104 total time=   2.6s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.090 total time=   2.7s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.778 total time=   1.4s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.764 total time=   1.4s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.821 total time=   1.3s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.802 total time=   1.2s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.769 total time=   1.2s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.344 total time=   2.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.047 total time=   2.7s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.156 total time=   2.9s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.033 total time=   2.8s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.033 total time=   2.6s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.354 total time=   2.9s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.090 total time=   2.9s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.170 total time=   3.4s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.061 total time=   2.9s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.061 total time=   2.9s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.349 total time=   2.7s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.071 total time=   3.0s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.165 total time=   2.9s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.052 total time=   3.7s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.047 total time=   2.6s
# [CV 1/5] END C=10, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.778 total time=   1.2s
# [CV 2/5] END C=10, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   1.3s
# [CV 3/5] END C=10, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.825 total time=

# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.373 total time=   1.5s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.363 total time=   1.6s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.783 total time=   1.4s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.774 total time=   1.4s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.811 total time=   1.5s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.792 total time=   1.4s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.778 total time=   1.7s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.764 total time=   1.5s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.769 total time=   1.2s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.802 total time=   1.2s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.783 total time=   1.2s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.783 total time=   1.2s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.778 total time=   1.2s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   1.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.825 total time=   1.2s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.802 total time=   1.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.769 total time=   1.3s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.778 total time=   1.4s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.741 total time=   1.4s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.764 total time=   1.2s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.778 total time=   1.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.778 total time=   1.2s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.774 total time=   1.5s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.759 total time=   1.5s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.811 total time=   1.6s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.797 total time=   1.6s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.797 total time=   1.8s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.283 total time=   1.2s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.193 total time=   1.0s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.406 total time=   1.0s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.316 total time=   1.0s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.321 total time=   1.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.778 total time=   1.2s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.764 total time=   1.2s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.825 total time=   1.2s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.802 total time=   1.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.769 total time=   1.3s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.316 total time=   2.6s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.325 total time=   2.4s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.325 total time=   2.4s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.392 total time=   2.4s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.316 total time=   2.4s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.769 total time=   1.8s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.774 total time=   1.7s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.811 total time=   1.5s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.792 total time=   1.5s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.788 total time=   1.5s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.774 total time=   1.3s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.774 total time=   1.3s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.825 total time=   1.3s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.802 total time=   1.3s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.783 total time=   1.5s
# CPU times: user 8min 58s, sys: 594 ms, total: 8min 58s
# Wall time: 9min 11s
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'class_weight': [None, 'balanced'],
#                           'gamma': [0.001, 0.0001],
#                           'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                           'random_state': [5]}],
#              verbose=3)

# %% [markdown]
# Определите гиперпараметры лучшей полученной модели.

# %%
cv.best_params_
# Out:
# {'C': 1000,
#  'class_weight': 'balanced',
#  'gamma': 0.0001,
#  'kernel': 'sigmoid',
#  'random_state': 5}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Выполните предсказание для тестовых данных при помощи лучшей полученной модели. Вычислите <code>f1_score(average='weighted')</code>.

# %%
y_pred = cv.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f'F1-score: {f1:.3f}')
# Out:
# F1-score: 0.771

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Уменьшение размерности

# %% [markdown]
# Обучение было долгим. Имеет смысл проверить, что будет если уменьшить размерность входных данных, например, при помощи <code>PCA</code>. Обучите модель <code>PCA(svd_solver='full')</code> на тренировочных данных и определите минимальное количество компонент, необходимое для того, чтобы уровень объясненной дисперсии был больше <code>0.95</code>.

# %%
pca = PCA(svd_solver='full')
pca.fit(X_train)

cumsum = pca.explained_variance_ratio_.cumsum()
n_components = (cumsum > 0.95).argmax() + 1
print(n_components)
# Out:
# 173

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Заново обучите модель <code>PCA(svd_solver='full')</code> на тренировочных данных с использованием полученного числа ГК. Примените полученное преобразование для тренировочных и тестовых данных.

# %%
pca = PCA(n_components=173, svd_solver='full')
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %% [markdown]
# Для полученных после <code>PCA</code> данных аналогично проделанному ранее, то есть используя <code>GridSearchCV()</code>, осуществите подбор гиперпараметров, указанных в вашем задании. Отдельно обратите внимание на время обучения моделей.

# %%
# %%time
cv_pca = GridSearchCV(SVC(), tuned_parameters, refit=True, verbose=3)
cv_pca.fit(X_train_pca, y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.344 total time=   0.1s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.340 total time=   0.1s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.340 total time=   0.1s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.340 total time=   0.1s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.340 total time=   0.1s
# [CV 1/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.425 total time=   0.2s
# [CV 2/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.396 total time=   0.1s
# [CV 3/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.420 total time=   0.2s
# [CV 4/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.401 total time=   0.1s
# [CV 5/5] END C=1, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0
5] END C=100, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.608 total time=   0.1s
# [CV 3/5] END C=100, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.670 total time=   0.2s
# [CV 4/5] END C=100, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.651 total time=   0.1s
# [CV 5/5] END C=100, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.618 total time=   0.1s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.127 total time=   0.2s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.156 total time=   0.2s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.066 total time=   0.2s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.108 total time=   0.2s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.104 total time=   0.2s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.759 total time=   0.1s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.745 total time=   0.1s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.792 total time=   0.1s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.778 total time=   0.1s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.745 total time=   0.2s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.774 total time=   0.1s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.807 total time=   0.2s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.788 total time=   0.2s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.783 total time=   0.1s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.066 total time=   0.2s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.071 total time=   0.2s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.047 total time=   0.2s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.052 total time=   0.2s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.052 total time=   0.2s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.698 total time=   0.2s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.726 total time=   0.2s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.759 total time=   0.2s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.726 total time=   0.2s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.764 total time=   0.2s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.637 total time=   0.2s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.670 total time=   0.2s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.689 total time=   0.2s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.693 total time=   0.2s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.703 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.396 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.368 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.392 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.382 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.001, kernel=poly, random_state=5;, score=0.382 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.764 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.741 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.807 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.783 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.001, kernel=rbf, random_state=5;, score=0.755 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.745 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.759 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.811 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.764 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.741 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.745 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.750 total time=   0.2s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.811 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.764 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=linear, random_state=5;, score=0.745 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.344 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   0.2s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=poly, random_state=5;, score=0.340 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.755 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.745 total time=   0.2s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.821 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.778 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=rbf, random_state=5;, score=0.774 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.750 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.807 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.792 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=None, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.792 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.434 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.396 total time=   0.2s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.420 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.429 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=poly, random_state=5;, score=0.434 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.764 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.741 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.807 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.783 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=5;, score=0.755 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.755 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.759 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.816 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, random_state=5;, score=0.736 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.750 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.764 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=5;, score=0.745 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.151 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.151 total time=   0.2s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.047 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.033 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=5;, score=0.033 total time=   0.2s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.755 total time=   0.1s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.774 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.830 total time=   0.2s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.783 total time=   0.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=5;, score=0.769 total time=   0.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.750 total time=   0.2s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.774 total time=   0.1s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.811 total time=   0.1s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.792 total time=   0.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, random_state=5;, score=0.783 total time=   0.2s
# CPU times: user 53.3 s, sys: 91.8 ms, total: 53.4 s
# Wall time: 53.6 s
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'class_weight': [None, 'balanced'],
#                           'gamma': [0.001, 0.0001],
#                           'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                           'random_state': [5]}],
#              verbose=3)

# %% [markdown]
# Определите гиперпараметры лучшей полученной модели.

# %%
cv_pca.best_params_
# Out:
# {'C': 1000,
#  'class_weight': 'balanced',
#  'gamma': 0.0001,
#  'kernel': 'rbf',
#  'random_state': 5}

# %% [markdown]
# Выполните предсказание для тестовых данных при помощи лучшей полученной модели. Вычислите <code>f1_score(average='weighted')</code>

# %%
y_pred = cv_pca.predict(X_test_pca)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f'F1-score: {f1:.3f}')
# Out:
# F1-score: 0.755

# %% [markdown]
# Видно, что качество модели изменилось незначительно, при этом время обучения существенно сократилось.
